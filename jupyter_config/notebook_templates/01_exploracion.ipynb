# %% [markdown]
# # Exploración de datasets
# Notebook base para explorar tablas y CSV locales.

# %%
import os
import sqlite3
import pandas as pd

db_path = os.environ.get('OWID_DB_PATH')
conn = sqlite3.connect(db_path) if db_path else None
db_path
