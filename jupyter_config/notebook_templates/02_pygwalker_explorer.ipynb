# %% [markdown]
# # PyGWalker Explorer
# Template rápido para explorar un DataFrame con PyGWalker.

# %%
import pandas as pd
import pygwalker as pyg

df = pd.DataFrame({'x':[1,2,3], 'y':[2,3,5]})
pyg.walk(df)
